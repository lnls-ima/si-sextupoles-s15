# %% [markdown]
# # Rotating Coild Data Analysis for SI S15-Fam2 Magnets

# %% [markdown]
# ## Import libraries and Load measurement data

# %%
import sys
import numpy as np
import matplotlib
from matplotlib import gridspec

matplotlib.use('Qt5Agg')

# %matplotlib notebook

import matplotlib.pyplot as plt
from lnls.rotcoil import *

# %%
# Define serial numbers, one for each magnet

serials = [
    '005', 
    '007', # large exc. error at high currents
    '011', '012', '013', '015', '019', '020', '022', '023', 
    '024', '025', '028', '039', '042', '049', '063', '064', '065', '067', 
    '068', '071', '073', '074', '075', '077', '080', '081', '082', '083', 
    '084', '085', '086', '088', '089', '090', '094', '095', '096', '097', 
    '098', '108', '112', '114', '115', '125', '129', '135', '144', '147', 
    '150', '151', '152', '153', '158', '160', '161', '163', '169', '173', 
    '178', '182', '196', '198', '200', '201', '202', '203', '204', '205', 
    '208', '211', '214', '217', '224', '225', '226', '233', '235', '241', 
    '243', '247', '250', '252', '254', '255', '259', '260', '262', '264', 
    '265', '266', '268', '269', '270', '273', '279', '280', '282', '283', 
    '284', '285', '286', 
]

# Load all data
RotCoilMeas_SISextS15.family_folder = 'family_2/'
data = MagnetsAnalysis(RotCoilMeas_SISextS15, serials)
data.init()

# Print info
data.print_info()
# Out:
# index: 00, serial_number: 005, data sets: ['M1']
# index: 01, serial_number: 007, data sets: ['M1']
# index: 02, serial_number: 011, data sets: ['M1']
# index: 03, serial_number: 012, data sets: ['M1']
# index: 04, serial_number: 013, data sets: ['M1', 'anterior']
# index: 05, serial_number: 015, data sets: ['M1']
# index: 06, serial_number: 019, data sets: ['M1', 'anterior']
# index: 07, serial_number: 020, data sets: ['M1']
# index: 08, serial_number: 022, data sets: ['M1']
# index: 09, serial_number: 023, data sets: ['M1']
# index: 10, serial_number: 024, data sets: ['M1']
# index: 11, serial_number: 025, data sets: ['M1']
# index: 12, serial_number: 028, data sets: ['M1']
# index: 13, serial_number: 039, data sets: ['M1']
# index: 14, serial_number: 042, data sets: ['M1']
# index: 15, serial_number: 049, data sets: ['M1']
# index: 16, serial_number: 063, data sets: ['M1']
# index: 17, serial_number: 064, data sets: ['M1']
# index: 18, serial_number: 065, data sets: ['M1']
# index: 19, serial_number: 067, data sets: ['M1']
# index: 20, serial_number: 068, data sets: ['M1']
# index: 21, serial_number: 071, data sets: ['M1']
# index: 22, serial_number: 073, data sets: ['M1']
# index: 23, serial_number: 074, data sets: ['M1']
# index: 24, serial_number: 075, data sets: ['M1']
# index: 25, serial_number: 077, data sets: ['M1']
# index: 26, serial_number: 080, data sets: ['M1']
# index: 27, serial_number: 081, data sets: ['M1']
# index: 28, serial_number: 082, data sets: ['M1']
# index: 29, serial_number: 083, data sets: ['M1']
# index: 30, serial_number: 084, data sets: ['M1']
# index: 31, serial_number: 085, data sets: ['M1']
# index: 32, serial_number: 086, data sets: ['M1']
# index: 33, serial_number: 088, data sets: ['M1']
# index: 34, serial_number: 089, data sets: ['M1']
# index: 35, serial_number: 090, data sets: ['M1']
# index: 36, serial_number: 094, data sets: ['M1']
# index: 37, serial_number: 095, data sets: ['M1']
# index: 38, serial_number: 096, data sets: ['M1']
# index: 39, serial_number: 097, data sets: ['M1']
# index: 40, serial_number: 098, data sets: ['M1']
# index: 41, serial_number: 108, data sets: ['M1']
# index: 42, serial_number: 112, data sets: ['M1']
# index: 43, serial_number: 114, data sets: ['M1']
# index: 44, serial_number: 115, data sets: ['M1']
# index: 45, serial_number: 125, data sets: ['M1']
# index: 46, serial_number: 129, data sets: ['M1']
# index: 47, serial_number: 135, data sets: ['M1']
# index: 48, serial_number: 144, data sets: ['M1']
# index: 49, serial_number: 147, data sets: ['M1']
# index: 50, serial_number: 150, data sets: ['M1']
# index: 51, serial_number: 151, data sets: ['M1']
# index: 52, serial_number: 152, data sets: ['M1']
# index: 53, serial_number: 153, data sets: ['M1']
# index: 54, serial_number: 158, data sets: ['M1']
# index: 55, serial_number: 160, data sets: ['M1']
# index: 56, serial_number: 161, data sets: ['M1']
# index: 57, serial_number: 163, data sets: ['M1']
# index: 58, serial_number: 169, data sets: ['M1']
# index: 59, serial_number: 173, data sets: ['M1']
# index: 60, serial_number: 178, data sets: ['M1']
# index: 61, serial_number: 182, data sets: ['M1']
# index: 62, serial_number: 196, data sets: ['M1']
# index: 63, serial_number: 198, data sets: ['M1']
# index: 64, serial_number: 200, data sets: ['M1']
# index: 65, serial_number: 201, data sets: ['M1']
# index: 66, serial_number: 202, data sets: ['M1']
# index: 67, serial_number: 203, data sets: ['M1']
# index: 68, serial_number: 204, data sets: ['M1']
# index: 69, serial_number: 205, data sets: ['M1']
# index: 70, serial_number: 208, data sets: ['M1']
# index: 71, serial_number: 211, data sets: ['M1']
# index: 72, serial_number: 214, data sets: ['M1']
# index: 73, serial_number: 217, data sets: ['M1']
# index: 74, serial_number: 224, data sets: ['M1']
# index: 75, serial_number: 225, data sets: ['M1']
# index: 76, serial_number: 226, data sets: ['M1']
# index: 77, serial_number: 233, data sets: ['M1']
# index: 78, serial_number: 235, data sets: ['M1']
# index: 79, serial_number: 241, data sets: ['M1']
# index: 80, serial_number: 243, data sets: ['M1']
# index: 81, serial_number: 247, data sets: ['M1']
# index: 82, serial_number: 250, data sets: ['M1']
# index: 83, serial_number: 252, data sets: ['M1']
# index: 84, serial_number: 254, data sets: ['M1']
# index: 85, serial_number: 255, data sets: ['M1']
# index: 86, serial_number: 259, data sets: ['M1']
# index: 87, serial_number: 260, data sets: ['M1']
# index: 88, serial_number: 262, data sets: ['M1']
# index: 89, serial_number: 264, data sets: ['M1']
# index: 90, serial_number: 265, data sets: ['M1']
# index: 91, serial_number: 266, data sets: ['M1']
# index: 92, serial_number: 268, data sets: ['M1']
# index: 93, serial_number: 269, data sets: ['M1']
# index: 94, serial_number: 270, data sets: ['M1', 'anterior']
# index: 95, serial_number: 273, data sets: ['M1', 'Anterior']
# index: 96, serial_number: 279, data sets: ['M1']
# index: 97, serial_number: 280, data sets: ['M1']
# index: 98, serial_number: 282, data sets: ['M1']
# index: 99, serial_number: 283, data sets: ['M1', 'anterior']
# index: 100, serial_number: 284, data sets: ['M1']
# index: 101, serial_number: 285, data sets: ['M1']
# index: 102, serial_number: 286, data sets: ['M1']

# %% [markdown]
# ## Maximum Integrated Quadrupole

# %%
# gets integrated strength at maximum current for all magnets
data.main_intmpole_at_max_current('M1')
# Out:
# index:00, serial:005, idx:13, max_current:  +167.7979 [A], diff_spec: -0.03 [%]
# index:01, serial:007, idx:13, max_current:  +167.7976 [A], diff_spec: +1.24 [%]
# index:02, serial:011, idx:13, max_current:  +167.7974 [A], diff_spec: -0.07 [%]
# index:03, serial:012, idx:13, max_current:  +167.7979 [A], diff_spec: -0.02 [%]
# index:04, serial:013, idx:13, max_current:  +167.7981 [A], diff_spec: -0.20 [%]
# index:05, serial:015, idx:13, max_current:  +167.7991 [A], diff_spec: -0.06 [%]
# index:06, serial:019, idx:13, max_current:  +167.7982 [A], diff_spec: -0.04 [%]
# index:07, serial:020, idx:13, max_current:  +167.7971 [A], diff_spec: -0.02 [%]
# index:08, serial:022, idx:13, max_current:  +167.7963 [A], diff_spec: -0.15 [%]
# index:09, serial:023, idx:13, max_current:  +167.7979 [A], diff_spec: -0.08 [%]
# index:10, serial:024, idx:13, max_current:  +167.7973 [A], diff_spec: -0.09 [%]
# index:11, serial:025, idx:13, max_current:  +167.7983 [A], diff_spec: -0.13 [%]
# index:12, serial:028, idx:13, max_current:  +167.7988 [A], diff_spec: -0.18 [%]
# index:13, serial:039, idx:13, max_current:  +167.8012 [A], diff_spec: -0.14 [%]
# index:14, serial:042, idx:13, max_current:  +167.7983 [A], diff_spec: +0.06 [%]
# index:15, serial:049, idx:13, max_current:  +167.7989 [A], diff_spec: -0.23 [%]
# index:16, serial:063, idx:13, max_current:  +167.7969 [A], diff_spec: -0.23 [%]
# index:17, serial:064, idx:13, max_current:  +167.7963 [A], diff_spec: -0.15 [%]
# index:18, serial:065, idx:13, max_current:  +167.7979 [A], diff_spec: -0.27 [%]
# index:19, serial:067, idx:13, max_current:  +167.7997 [A], diff_spec: -0.29 [%]
# index:20, serial:068, idx:13, max_current:  +167.7976 [A], diff_spec: -0.21 [%]
# index:21, serial:071, idx:13, max_current:  +167.7970 [A], diff_spec: -0.28 [%]
# index:22, serial:073, idx:13, max_current:  +167.7978 [A], diff_spec: -0.23 [%]
# index:23, serial:074, idx:13, max_current:  +167.7984 [A], diff_spec: -0.22 [%]
# index:24, serial:075, idx:13, max_current:  +167.7993 [A], diff_spec: -0.18 [%]
# index:25, serial:077, idx:13, max_current:  +167.7981 [A], diff_spec: -0.28 [%]
# index:26, serial:080, idx:13, max_current:  +167.7987 [A], diff_spec: -0.33 [%]
# index:27, serial:081, idx:13, max_current:  +167.7981 [A], diff_spec: -0.28 [%]
# index:28, serial:082, idx:13, max_current:  +167.7983 [A], diff_spec: -0.27 [%]
# index:29, serial:083, idx:13, max_current:  +167.7971 [A], diff_spec: -0.30 [%]
# index:30, serial:084, idx:13, max_current:  +167.7969 [A], diff_spec: -0.26 [%]
# index:31, serial:085, idx:13, max_current:  +167.7977 [A], diff_spec: -0.19 [%]
# index:32, serial:086, idx:13, max_current:  +167.7974 [A], diff_spec: -0.18 [%]
# index:33, serial:088, idx:13, max_current:  +167.7978 [A], diff_spec: -0.08 [%]
# index:34, serial:089, idx:13, max_current:  +167.7980 [A], diff_spec: -0.14 [%]
# index:35, serial:090, idx:13, max_current:  +167.7983 [A], diff_spec: -0.10 [%]
# index:36, serial:094, idx:13, max_current:  +167.7980 [A], diff_spec: +0.06 [%]
# index:37, serial:095, idx:13, max_current:  +167.7997 [A], diff_spec: -0.04 [%]
# index:38, serial:096, idx:13, max_current:  +167.7991 [A], diff_spec: -0.04 [%]
# index:39, serial:097, idx:13, max_current:  +167.7986 [A], diff_spec: -0.09 [%]
# index:40, serial:098, idx:13, max_current:  +167.7997 [A], diff_spec: -0.06 [%]
# index:41, serial:108, idx:13, max_current:  +167.7982 [A], diff_spec: -0.06 [%]
# index:42, serial:112, idx:13, max_current:  +167.7975 [A], diff_spec: -0.12 [%]
# index:43, serial:114, idx:13, max_current:  +167.7976 [A], diff_spec: -0.03 [%]
# index:44, serial:115, idx:13, max_current:  +167.7987 [A], diff_spec: -0.17 [%]
# index:45, serial:125, idx:13, max_current:  +167.7981 [A], diff_spec: -0.17 [%]
# index:46, serial:129, idx:13, max_current:  +167.7988 [A], diff_spec: -0.16 [%]
# index:47, serial:135, idx:13, max_current:  +167.7978 [A], diff_spec: -0.06 [%]
# index:48, serial:144, idx:13, max_current:  +167.7983 [A], diff_spec: -0.27 [%]
# index:49, serial:147, idx:13, max_current:  +167.7988 [A], diff_spec: -0.18 [%]
# index:50, serial:150, idx:13, max_current:  +167.7977 [A], diff_spec: -0.18 [%]
# index:51, serial:151, idx:13, max_current:  +167.7985 [A], diff_spec: -0.33 [%]
# index:52, serial:152, idx:13, max_current:  +167.7983 [A], diff_spec: -0.27 [%]
# index:53, serial:153, idx:13, max_current:  +167.7989 [A], diff_spec: -0.31 [%]
# index:54, serial:158, idx:13, max_current:  +167.7984 [A], diff_spec: -0.14 [%]
# index:55, serial:160, idx:13, max_current:  +167.7978 [A], diff_spec: -0.17 [%]
# index:56, serial:161, idx:13, max_current:  +167.7971 [A], diff_spec: -0.17 [%]
# index:57, serial:163, idx:13, max_current:  +167.7981 [A], diff_spec: -0.18 [%]
# index:58, serial:169, idx:13, max_current:  +167.7980 [A], diff_spec: -0.22 [%]
# index:59, serial:173, idx:13, max_current:  +167.7979 [A], diff_spec: -0.18 [%]
# index:60, serial:178, idx:13, max_current:  +167.7986 [A], diff_spec: -0.18 [%]
# index:61, serial:182, idx:13, max_current:  +167.7980 [A], diff_spec: -0.21 [%]
# index:62, serial:196, idx:13, max_current:  +167.7977 [A], diff_spec: -0.21 [%]
# index:63, serial:198, idx:13, max_current:  +167.7974 [A], diff_spec: -0.22 [%]
# index:64, serial:200, idx:13, max_current:  +167.7990 [A], diff_spec: -0.16 [%]
# index:65, serial:201, idx:13, max_current:  +167.7974 [A], diff_spec: -0.14 [%]
# index:66, serial:202, idx:13, max_current:  +167.7989 [A], diff_spec: -0.03 [%]
# index:67, serial:203, idx:13, max_current:  +167.7976 [A], diff_spec: -0.12 [%]
# index:68, serial:204, idx:13, max_current:  +167.7987 [A], diff_spec: -0.19 [%]
# index:69, serial:205, idx:13, max_current:  +167.7967 [A], diff_spec: -0.20 [%]
# index:70, serial:208, idx:13, max_current:  +167.7983 [A], diff_spec: -0.18 [%]
# index:71, serial:211, idx:13, max_current:  +167.7993 [A], diff_spec: -0.03 [%]
# index:72, serial:214, idx:13, max_current:  +167.7990 [A], diff_spec: -0.26 [%]
# index:73, serial:217, idx:13, max_current:  +167.7993 [A], diff_spec: -0.29 [%]
# index:74, serial:224, idx:13, max_current:  +167.7976 [A], diff_spec: -0.15 [%]
# index:75, serial:225, idx:13, max_current:  +167.7986 [A], diff_spec: -0.17 [%]
# index:76, serial:226, idx:13, max_current:  +167.7994 [A], diff_spec: -0.16 [%]
# index:77, serial:233, idx:13, max_current:  +167.7977 [A], diff_spec: -0.28 [%]
# index:78, serial:235, idx:13, max_current:  +167.7964 [A], diff_spec: -0.13 [%]
# index:79, serial:241, idx:13, max_current:  +167.7978 [A], diff_spec: -0.21 [%]
# index:80, serial:243, idx:13, max_current:  +167.7986 [A], diff_spec: -0.03 [%]
# index:81, serial:247, idx:13, max_current:  +167.7979 [A], diff_spec: -0.23 [%]
# index:82, serial:250, idx:13, max_current:  +167.7979 [A], diff_spec: -0.20 [%]
# index:83, serial:252, idx:13, max_current:  +167.7991 [A], diff_spec: -0.18 [%]
# index:84, serial:254, idx:13, max_current:  +167.7966 [A], diff_spec: -0.18 [%]
# index:85, serial:255, idx:13, max_current:  +167.7982 [A], diff_spec: -0.20 [%]
# index:86, serial:259, idx:13, max_current:  +167.7989 [A], diff_spec: -0.16 [%]
# index:87, serial:260, idx:13, max_current:  +167.7974 [A], diff_spec: -0.16 [%]
# index:88, serial:262, idx:13, max_current:  +167.7976 [A], diff_spec: -0.14 [%]
# index:89, serial:264, idx:13, max_current:  +167.7973 [A], diff_spec: -0.12 [%]
# index:90, serial:265, idx:13, max_current:  +167.7976 [A], diff_spec: -0.17 [%]
# index:91, serial:266, idx:13, max_current:  +167.7980 [A], diff_spec: -0.18 [%]
# index:92, serial:268, idx:13, max_current:  +167.7976 [A], diff_spec: -0.23 [%]
# index:93, serial:269, idx:13, max_current:  +167.7977 [A], diff_spec: -0.14 [%]
# index:94, serial:270, idx:13, max_current:  +167.7982 [A], diff_spec: -0.13 [%]
# index:95, serial:273, idx:13, max_current:  +167.7985 [A], diff_spec: -0.21 [%]
# index:96, serial:279, idx:13, max_current:  +167.7975 [A], diff_spec: -0.08 [%]
# index:97, serial:280, idx:13, max_current:  +167.7982 [A], diff_spec: -0.16 [%]
# index:98, serial:282, idx:13, max_current:  +167.8008 [A], diff_spec: -0.06 [%]
# index:99, serial:283, idx:13, max_current:  +167.7985 [A], diff_spec: -0.09 [%]
# index:100, serial:284, idx:13, max_current:  +167.7964 [A], diff_spec: -0.10 [%]
# index:101, serial:285, idx:13, max_current:  +167.7977 [A], diff_spec: -0.13 [%]
# index:102, serial:286, idx:13, max_current:  +167.7957 [A], diff_spec: -0.11 [%]

# %%
# plot data comparison with spec
plt.figure()
data.main_intmpole_at_max_current_plot(plt)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Magnetic Center

# %%
# Horizontal center for all magnets x currents
plt.figure()
data.magnetic_center_direction_plot('M1', 'X', plt)
plt.show()

# Vertical center for all magnets y currents
plt.figure()
data.magnetic_center_direction_plot('M1', 'Y', plt)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# Horizontal center at maximum current [um]: +14.02 ± 6.52
# <img src="data:image/png;base64,..." width="640">
# Vertical center at maximum current [um]: +24.54 ± 4.33

# %%
# Horizontal and vertical positions of all magnets
plt.figure()
data.magnetic_center_plot('M1', plt)
plt.show()

# Transverse plane positions
plt.figure()
data.magnetic_center_transverse_plot('M1', plt)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Ramp Up

# %%
# Plot rampup integrated strength of main multipole and compare it to nominal values and maximum spec

plt.figure()
data.rampup_excitation_curve_plot('M1', plt)
plt.show()

# Print currents for nominal strengths
print()
d = data.tmpl.get_nominal_main_intmpole_values(3.0)
for fam, gl in d.items():
    c = data.tmpl.rampup_main_mpole_2_curr('M1', gl)
    print('{:<15s}: {:05.1f} A'.format(fam, c))
# Out:
# <img src="data:image/png;base64,..." width="640">
# Nominal Integrated Sextupole [T/m]:
# SI-Fam:MA-SFA0  : -78.908989
# SI-Fam:MA-SFB0  : -110.686722
# SI-Fam:MA-SFP0  : -110.686722
# SI-Fam:MA-SFA1  : -287.941796
# SI-Fam:MA-SFB1  : -342.058583
# SI-Fam:MA-SFP1  : -344.112004
# SI-Fam:MA-SFA2  : -226.310360
# SI-Fam:MA-SFB2  : -296.936318
# SI-Fam:MA-SFP2  : -297.961227
# SI-Fam:MA-SDA0  : -121.334488
# SI-Fam:MA-SDB0  : -97.480736
# SI-Fam:MA-SDP0  : -97.480736
# SI-Fam:MA-SDA1  : -244.648996
# SI-Fam:MA-SDB1  : -212.600926
# SI-Fam:MA-SDP1  : -213.606771
# SI-Fam:MA-SDA2  : -133.373267
# SI-Fam:MA-SDB2  : -183.469072
# SI-Fam:MA-SDP2  : -183.548477
# SI-Fam:MA-SDA3  : -210.056515
# SI-Fam:MA-SDB3  : -260.899088
# SI-Fam:MA-SDP3  : -261.416946
#
# SI-Fam:MA-SFA0 : 035.0 A
# SI-Fam:MA-SFB0 : 049.1 A
# SI-Fam:MA-SFP0 : 049.1 A
# SI-Fam:MA-SFA1 : 128.9 A
# SI-Fam:MA-SFB1 : 156.8 A
# SI-Fam:MA-SFP1 : 158.1 A
# SI-Fam:MA-SFA2 : 100.5 A
# SI-Fam:MA-SFB2 : 133.3 A
# SI-Fam:MA-SFP2 : 133.8 A
# SI-Fam:MA-SDA0 : 053.8 A
# SI-Fam:MA-SDB0 : 043.2 A
# SI-Fam:MA-SDP0 : 043.2 A
# SI-Fam:MA-SDA1 : 108.8 A
# SI-Fam:MA-SDB1 : 094.3 A
# SI-Fam:MA-SDP1 : 094.8 A
# SI-Fam:MA-SDA2 : 059.1 A
# SI-Fam:MA-SDB2 : 081.3 A
# SI-Fam:MA-SDP2 : 081.4 A
# SI-Fam:MA-SDA3 : 093.2 A
# SI-Fam:MA-SDB3 : 116.3 A
# SI-Fam:MA-SDP3 : 116.6 A

# %%
# Plot rampup dispersion amongst magnets

plt.figure()
data.rampup_excitation_curve_dispersion_plot('M1', plt)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Print random integrated main strength for various currents

data.rampup_excitation_curve_rms_error_print('M1')
# Out:
# current 00:   +0.001 [A], rms_error:  3.8093 [%], max_error:  8.5265 [%]
# current 01:   +1.995 [A], rms_error:  1.2436 [%], max_error:  3.0354 [%]
# current 02:   +3.998 [A], rms_error:  0.6713 [%], max_error:  1.6661 [%]
# current 03:   +5.997 [A], rms_error:  0.4303 [%], max_error:  1.0582 [%]
# current 04:   +7.996 [A], rms_error:  0.3030 [%], max_error:  0.7780 [%]
# current 05:   +9.996 [A], rms_error:  0.2281 [%], max_error:  0.6004 [%]
# current 06:  +29.996 [A], rms_error:  0.1131 [%], max_error:  0.2887 [%]
# current 07:  +49.995 [A], rms_error:  0.1106 [%], max_error:  0.2846 [%]
# current 08:  +69.995 [A], rms_error:  0.1068 [%], max_error:  0.2695 [%]
# current 09:  +89.998 [A], rms_error:  0.1033 [%], max_error:  0.2678 [%]
# current 10: +109.996 [A], rms_error:  0.1014 [%], max_error:  0.3082 [%]
# current 11: +129.996 [A], rms_error:  0.1019 [%], max_error:  0.3657 [%]
# current 12: +149.997 [A], rms_error:  0.1138 [%], max_error:  0.6420 [%]
# current 13: +167.798 [A], rms_error:  0.1600 [%], max_error:  1.3879 [%]

# %%
# Plot Integrated Quadrupole Error for maximum current

plt.figure()
data.rampup_excitation_curve_rms_error_plot(plt)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Gradient Roll Error

# %%
plt.figure()
data.rotation_error_vs_current_plot('M1', 3.0, plt)
plt.show()

# i=6:  SFA0 I=30A
# i=13: SFB1|SFP1 I=168A
curr_idx = [6, 13]  
for i in curr_idx:
    plt.figure()
    spec, avg, std = data.rotation_error_plot('M1', plt, i)
    plt.show()
    print('Angle error (Spec): {:+.3f} mrad'.format(spec))
    print('Angle error (Avg) : {:+.3f} mrad'.format(avg))
    print('Angle error (Std) : {:+.3f} mrad'.format(std))
# Out:
# <img src="data:image/png;base64,..." width="640">
# Currents for nominal strengths:
# SI-Fam:MA-SFA0: 35.0 A
# SI-Fam:MA-SDP0: 43.2 A
# SI-Fam:MA-SDB0: 43.2 A
# SI-Fam:MA-SFB0: 49.1 A
# SI-Fam:MA-SFP0: 49.1 A
# SI-Fam:MA-SDA0: 53.8 A
# SI-Fam:MA-SDA2: 59.1 A
# SI-Fam:MA-SDB2: 81.3 A
# SI-Fam:MA-SDP2: 81.4 A
# SI-Fam:MA-SDA3: 93.2 A
# SI-Fam:MA-SDB1: 94.3 A
# SI-Fam:MA-SDP1: 94.8 A
# SI-Fam:MA-SFA2: 100.5 A
# SI-Fam:MA-SDA1: 108.8 A
# SI-Fam:MA-SDB3: 116.3 A
# SI-Fam:MA-SDP3: 116.6 A
# SI-Fam:MA-SFA1: 128.9 A
# SI-Fam:MA-SFB2: 133.3 A
# SI-Fam:MA-SFP2: 133.8 A
# SI-Fam:MA-SFB1: 156.8 A
# SI-Fam:MA-SFP1: 158.1 A
# <img src="data:image/png;base64,..." width="640">
# Angle error (Spec): +0.300 mrad
# Angle error (Avg) : +0.280 mrad
# Angle error (Std) : +0.245 mrad
# <img src="data:image/png;base64,..." width="640">
# Angle error (Spec): +0.300 mrad
# Angle error (Avg) : +0.079 mrad
# Angle error (Std) : +0.142 mrad

# %% [markdown]
# ## Hysteresis

# %%
# Absolute
plt.figure()
data.hysteresis_absolute_plot('M1', plt)
plt.show()

# Relative
plt.figure()
data.hysteresis_relative_plot('M1', plt)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Save Excitation Data Files

# %%
# save average excitation data to file

data.save_excdata_average('M1')

# %%
# save excitation data of all magnets to separate files
data.save_excdata_individuals('M1')

# %% [markdown]
# ## Multipoles

# %%
# Horizontal kick

curr_idx = [6, 13]
for i in curr_idx:
    plt.figure(figsize=(9,4))
    data.multipole_errors_kickx_plot('M1', plt, curr_idx=i, energy=3.0, 
                                     excluded_monomials_plot1=(3,),
                                     excluded_monomials_plot2=(1,2,3,))
    plt.show()
# Out:
# <img src="data:image/png;base64,..." width="900">
# <img src="data:image/png;base64,..." width="900">

# %%
# Vertical kick

curr_idx = [6, 13]
for i in curr_idx:
    plt.figure(figsize=(9,4))
    data.multipole_errors_kicky_plot('M1', plt, curr_idx=i, energy=3.0, 
                                     excluded_monomials_plot1=(),
                                     excluded_monomials_plot2=(1,2,))
    plt.show()
# Out:
# <img src="data:image/png;base64,..." width="900">
# <img src="data:image/png;base64,..." width="900">

# %% [markdown]
# # Magnets Sorting

# %%
med = 'M1'
print('Rampup')
c, gl = data.tmpl.get_rampup(med)
for i in range(len(c)):
    print('{:02d}: I = {:8.4f} A => GL = {:+.4f} T'.format(i, c[i], gl[i]))
# Out:
# Rampup
# 00: I =   0.0010 A => GL = -2.6327 T
# 01: I =   1.9951 A => GL = -6.6626 T
# 02: I =   3.9977 A => GL = -10.8152 T
# 03: I =   5.9967 A => GL = -15.0136 T
# 04: I =   7.9958 A => GL = -19.2535 T
# 05: I =   9.9958 A => GL = -23.5304 T
# 06: I =  29.9955 A => GL = -67.6044 T
# 07: I =  49.9943 A => GL = -112.7050 T
# 08: I =  69.9951 A => GL = -157.9716 T
# 09: I =  89.9983 A => GL = -203.0277 T
# 10: I = 109.9962 A => GL = -247.2895 T
# 11: I = 129.9961 A => GL = -290.3020 T
# 12: I = 149.9972 A => GL = -330.7421 T
# 13: I = 167.7979 A => GL = -360.1398 T

# %%
# Print README Files

currents, _ = data.tmpl.get_rampup('M1')
stdout = sys.stdout
for cidx in range(1,len(currents)):
    sys.stdout = open('README-FAM2-{:.0f}A.md'.format(currents[cidx]), 'w')
    data.readme_print('M1', cidx)
    sys.stdout.flush()
sys.stdout = stdout

# %%
# Print Multipoles Files

currents, _ = data.tmpl.get_rampup('M1')
stdout = sys.stdout
for cidx in range(1,len(currents)):
    sys.stdout = open('MULTIPOLES-FAM2-{:.0f}A.txt'.format(currents[cidx]), 'w')
    data.readme_multipoles_print('M1', cidx)
    sys.stdout.flush()
sys.stdout = stdout
